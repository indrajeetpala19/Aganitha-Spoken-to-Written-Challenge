# %%
# WE START BY DEFINING A SET OF RULES FOR DESIGNING ANY STANDARD NLP LIBRARY
# RULE 1 --- CONVERT NUMBERED WORDS TO ACTUAL NUMBERS
# RULE 2 --- CONVERTING POSITIONS INTO NUMBERS UP TO WHICH THE CORRESPONDING CHARACTER WILL BE WRITTEN 
            # TRIPLE A : CONVERT TRIPLE TO 3, WRITE A FOR THREE TIMES --- AAA
# RULE 3 --- MERGE THE SPACE BETWEEN ANT TWO SINGLE CHARACTERS IF THE SECOND SINGLE CHARACTER IS M

def lib_rules():
    rules = {"Numbers":{
                        "zero": 0,
                        "one" : 1,
                        "two": 2,
                        "three": 3,
                        "four": 4,
                        "five": 5,
                        "six": 6,
                        "seven": 7,
                        "eight": 8,
                        "nine": 9,
                        "ten": 10,
                        "twenty": 20,
                        "thirty": 30,
                        "forty": 40,
                        "fifty": 50,
                        "sixty": 60,
                        "seventy": 70,
                        "eighty": 80,
                        "ninety": 90,
                        "hundred": 100
                        },
            "Positions": {
                         "single":1,
                         "double":2,
                         "triple":3,
                         "quadruple":4,
                         "quintuple":5,
                         "sextuple":6,
                         "septuple":7,
                         "octuple":8,
                         "nonuple":9,
                         "decuple":10
                      },
            "Combine": {
                          "A M": "AM",
                          "B M": "BM",
                          "C M": "CM",
                          "D M": "DM".
                          "E M": "EM",
                          "F M": "FM",
                          "G M": "GM",
                          "H M": "HM",
                          "I M": "IM",
                          "J M": "JM",
                          "K M": "KM",
                          "L M": "LM",
                          "M M": "MM",
                          "N M": "NM",
                          "O M": "OM",
                          "P M": "PM",
                          "Q M": "QM",
                          "R M": "RM",
                          "S M": "SM",
                          "T M": "TM",
                          "U M": "UM",
                          "V M": "VM",
                          "W M": "WM",
                          "X M": "XM",
                          "Y M": "YM",
                          "Z M": "ZM"
                       }
            }
    return rules
